# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
energy_ccsdt = -100.2061487621313

# %%
df = pd.read_csv("hf_energy_vs_bond_dim.csv", index_col="i")
print(df.head())
# Out:
#    chi  d     energy
# i
# 0    5  0 -85.843346
# 1   10  0 -91.819350
# 2   15  0 -98.035037
# 3   20  0 -99.469182
# 4   25  0 -99.365675

# %%
df["error"] = abs(df["energy"] - energy_ccsdt)
print(df.head())
# Out:
#    chi  d     energy      error
# i
# 0    5  0 -85.843346  14.362802
# 1   10  0 -91.819350   8.386799
# 2   15  0 -98.035037   2.171112
# 3   20  0 -99.469182   0.736966
# 4   25  0 -99.365675   0.840474

# %%
fig, ax = plt.subplots()
ax.set_yscale("log")
sns.lineplot(ax=ax, data=df, x="chi", y="error", hue="d")
# Out:
# <Axes: xlabel='chi', ylabel='error'>
