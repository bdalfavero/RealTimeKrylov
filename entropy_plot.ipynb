# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("hf_entropies.csv", index_col="i")
print(df.head())
# Out:
#    chi    t   entropy
# i
# 0    4  0.0  0.626578
# 1    4  0.0  0.631624
# 2    4  0.2  0.652112
# 3    4  0.4  0.670478
# 4    4  0.6  0.680938

# %%
sns.lineplot(data=df, x="t", y="entropy", hue="chi")
# Out:
# <Axes: xlabel='t', ylabel='entropy'>
